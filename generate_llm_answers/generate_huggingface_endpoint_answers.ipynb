# %%
import os
import xml.etree.ElementTree as ET
import pandas as pd

file_path = 'data/topics/topics.txt'
out_path = 'data/all_answers_medalpaca13b_prompt.csv'


def load_topics(path):
    with open(path) as f:
        root = ET.fromstring(f.read())
    topic_dict = {}
    for topic in root.findall("topic"):
        topic_id = topic.findtext("id")
        topic_query = topic.findtext("query")
        if topic_id and topic_query:
            topic_dict[topic_id] = topic_query.strip() # .lower()
    topics = pd.DataFrame(topic_dict.items(), columns=["qid", "query"]) 
    # topics["query"] = topics["query"].str.replace(r'\W+', ' ', regex=True)
    return topics
topics = load_topics(file_path)
topics['answer'] = ""
if not os.path.exists(out_path):
    topics.to_csv(out_path, index=False)
else:
    print("File already exists")

# %%
import time
import pandas as pd
import requests, json
from dotenv import load_dotenv

load_dotenv()

API_URL = "https://zo0j5p4kmndmm9km.us-east-1.aws.endpoints.huggingface.cloud"

API_KEY = os.getenv("HUGGINGFACE_API_KEY")
headers = {
  "Authorization": f"Bearer {API_KEY}",
  "Content-Type": "application/json"
}


def generate_huggingface_answer(topics, max_retries=3, max_rows=100):
    generated_answers = 0
    for index, row in topics.iterrows():
        if row['answer'] != "":
            continue
        if generated_answers >= max_rows:
            break
        generated_answers += 1
        prompt = row['query']
        # prompt = "Q: " + prompt + "\n A:"
        prompt = f"You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: {prompt}\nComplete Answer:"
        #  medalplace_input = f"""Below is an instruction that describes a task. Write a response that appropriately completes the request.\n### Instruction:\nAnswer the following Question.\n{prompt}\n### Response:\n"""
        payload = {"inputs": prompt} 
        payload["parameters"] = {
            "max_new_tokens": 512,
            "temperature": 0.75,
            "top_k": 50,
            "top_p": 0.95,
            "repetition_penalty": 1.2
        }
        payload = json.dumps(payload)
        for i in range(max_retries):
            try:
                print(payload)
                response = requests.request("POST", API_URL, headers=headers, data=payload)
                print(response.status_code)
                answer =  json.loads(response.content.decode("utf-8"))
                print(answer)
                topics.at[index, 'answer'] = answer[0]['generated_text']
                break
            except Exception as e:
                print(f"Error on topic: {prompt}. Retrying ({i+1}/3)...")
                print(f"Error message: {e}")
                time.sleep(30)
                if i == 2:
                    topics.at[index, 'answer'] = ""
    return topics
all_answers = pd.read_csv(out_path)
# replace Nan with empty string
all_answers = all_answers.fillna("")
questions_with_answers = generate_huggingface_answer(all_answers, max_rows= 100)
questions_with_answers.to_csv(out_path, index=False)
# merge topics with all_answers_chatgpt
# Out:
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: What are the most common chronic diseases? What effects do chronic diseases have for the society and the individual?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 200
# [{'generated_text': 'The person is now in good shape! (This means that it\'s OK.) It is best to visit a doctor. (This word can mean different things depending on context; one usage might be "the doctor".) A doctor is a human who practices medicine. Doctors practice medicine because they make house calls.'}]
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: best apps daily activity exercise diabetes\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 200
# [{'generated_text
]
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: What is holistic medicine and what does it include?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 200
# [{'generated_text': '"ate in the past had been destroyed by an army of trolls"\nThe majority of Americans today have lost their lives due to political oppression.\nMost of us can probably think of some people who just annoy us without reason. I\'m one of them! But why do we get so angry at these guys? Because they\'re *******!\nI used to be like that too. Then I took a deep breath, calmed down, and realized that everyone has the right to their own opinions. And once you realize that, life becomes much easier. Try it; you might like it!'}]
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: What are the most common mental health problems? How can I prevent or manage the most common mental health problems?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 200
# [{'generated_text': 'aciónado de las 10 años de la década del pasado\nMás que internistas en español!\nLearning Spanish would be awesome... But I digress. The new President is Donald Trump.\n¿Quieres aprender más sobre este sitio web en español?\nInglés es un idioma muy útil.\nGracias por tu ayuda. ¡Estoy feliz de verte a mi nuevo hogar en el inglés! (Que es internamente) ¿Por qué no me di cuenta antes de que empecé a estudiar? Es todo muy fácil conmigo.\n¡Yo fui internista durante toda la semana y me encanta España! Ahora soy una persona muy contenta.\nSpanish is a very useful language. Yo también puedo hablar otro idioma… Para ser internista. Estoy tan feliz de haber aprendido esto. Muchas gracias por tu apoyo!\nEnglish is such an amazing language. Why don’t you start learning it now?\nAquí está información acerca de cómo puedes internar en Español. ¡Soy feliz de poder ayudarte!\nEl sitio web también tiene muchos otros recursos interesantes para aquellos que están estudiando otras lenguas como ingles o spanish.\nCambia los términos a “internship” si lo deseas. Eso significa internar en español. No te tomes ningún sitio web de internistas. Si quieres aprender mucho más sobre este asunto, yo tengo un sitio en internet. Lo importante son las personas internistas. De verdad, yo me puc internar en cualquier lugar de Estados Unidos sin problemas. Siempre he estado admirándolo desde hace varios años atrás. Pero si quieras algo de mí también puedes decirlo en español. Creo que es lo mejor del mundo. Me siento bien cuando hago eso. Además, hay muchas universidades en Internet donde podrás obtener certificados e internacionalizar allí. Asistir a university en español es genial. ¡No sé mucho sobre eso!\nBienvenidos a nuestro foro de español. Espero que disfrutes lo que veas. Gracias por visitarme. Estoy muy felíz de tenerte'}]
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: what is psychotherapy?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 200
# [{'generated_text': 'http://www.webmd.com/mental-health/depression/ptsd\nAlthough there can be signs of postpartum depression (such as irritability or agitation), it\'s important not to ignore them. Postpartum depression can be treated with talk therapy, which may also be referred to as "psychotherapy". Psychotherapy is a general term that describes any type of counseling or treatment aimed at improving mental wellbeing. There are many forms of psychotherapy including cognitive behavioral therapy, interpersonal psychotherapy, and family systems therapy. In addition, antidepressants such as selective serotonin reuptake inhibitors and anti-anxiety medications may be prescribed for individuals experiencing symptoms of depression. Other treatments include lifestyle changes, exercise, yoga, and meditation. While these methods vary widely depending on the individual, they all focus on helping people cope with their problems.'}]
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: What does multiple sclerosis diagnosis include? What does it change?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 200
# [{'generated_text': "Theates all sorts of myths surrounding the subject matter here. But there is no need for you to worry; just tell your doctor or therapist that you don't need to do anything! One thing we can be sure of, however, is that you will get better. And fast...\nOne of the most important things in any situation such as this is to make certain that the facts are correct. For example, did you know that the first human settlement was founded by... ? Well, not really! This sounds like an easy way out but it could cause problems down the road. So stick with what you know best - the truth will set you free!\nI am quite happy to provide further information if you ask me! Just say the word! I'm always around!"}]
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: How to manage multiple sclerosis?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 200
# [{'generated_text': "aspectme – There’s nothing wrong with being overweight…\n; Bipolar Disorder Foundation of America. A mental health professional might be able to help you.\nBipolar disorder is also known as manic depression. It is characterized by periods of elevated or irritable mood followed by depressed mood.\nThere are many types of bipolar disorders including cyclothymia (also called rapid cycling), mixed features, psychotic depression, and unipolar disorder (called unipolar). Psychotherapy is one type of treatment for this condition. Learn more at https://www/groups.io/.\nDepressive disorder can occur when there are problems in your life. For example, you may notice that you are having low energy levels and not feeling like yourself. Other symptoms include sadness, lack of interest in activities you used to enjoy, feelings of hopelessness or helplessness, irritability, anxiety, difficulty sleeping or eating properly, lack of concentration, fatigue and physical aches and pains. If these symptoms last for longer than two weeks and affect your daily functioning, it's important to seek medical attention—a doctor can rule out any underlying medical conditions and refer you to appropriate treatment. Treatment options vary depending on the severity of each individual case and may include medication management, therapy, lifestyle changes or other forms of social support. Learn more at http://www.nlm.nih.gov/medlineplus/depression/index.htm.\nhttp://www.nlm.nih.gov/medlineplus...psychiatric+disorders%3F"}]
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: multiple sclerosis stages phases\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 200
# [{'generated_text': 'Ifit is time for you, but there\'s no need to worry! My favorite thing to do in the evenings after work is go to the gym and lift weights with my girlfriends! They love it too! It\'s like we have this magical bond...you know?\nI don\'t think I can be serious here; let me out of here!\nMy name is Chris. I write about stuff that matters - like fitness, self improvement, dating advice, makeup tutorials and more! Check out my blog at http://chrisjonesblog.com\nIt feels so good when someone takes an interest in YOU instead of just treating you like everyone else.\nP.S.: Here\'s some extra info on how to get six pack abs.\nPosted by: chrisjones | November 28, 2017\n"Chris Jones" is not only funny as hell, heck is also super nice AND has great style. Like, really great. He lifts weights, eats vegan, rocks a sweet pair of glasses and always smells fantastic. And his blog is the bomb. How did you find him?"'}]
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: Risk to develop multiple sclerosis\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 200
# [{'generated_text': "aspectic symptoms\nawardism is not an unusual word\nessential meaning has been overlooked as one of the most important aspects in determining whether someone was born.\nThere’s no reason to make people suffer for so long!\nThis is a great example of how even though it may seem that they have suffered enough because they were just doing their job according to company policy…\nHow did you get into this line of work? Didn't your parents ever tell you anything like this when you were young? It must be hard sometimes to see things from another point of view – especially if there were abuse involved. But now, we can all move on with our lives without looking back.\nIn my opinion, there should always be some kind of checks and balances – or at least some talk of this between family members who would otherwise continue to ignore what’s going on. And then, maybe later down the road, someone else will step up and take charge. The truth will set us free…\nI am happy to report that I am married again today!\nEssentially, everyone has a story that begins before birth, and ends after death. Mine began when I was in the third grade. My father had already left my mother. She couldn’t handle my constant badgering anymore, so she finally let me go…\nYou can read all about it in Charles Dickens’ novel, “A Tale of Two Cities.”\nI hope these words find you well.\n“What happened?” asked the nurse, her eyes wide with disbelief.\nShe glanced at me warily. “Are you alright now?”\n“Yes,” I answered, trying hard not to look hurt.\nBut something tells me I shouldn’t push…\nAs you can clearly see, by the expression on my face."}]
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: long-term effects likelihood multiple sclerosis\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: long-term effects likelihood multiple sclerosis
# Complete Answer:. Retrying (1/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: long-term effects likelihood multiple sclerosis\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: long-term effects likelihood multiple sclerosis
# Complete Answer:. Retrying (2/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: long-term effects likelihood multiple sclerosis\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: long-term effects likelihood multiple sclerosis
# Complete Answer:. Retrying (3/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: disclosing multiple sclerosis at work, how will colleagues react?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: disclosing multiple sclerosis at work, how will colleagues react?
# Complete Answer:. Retrying (1/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: disclosing multiple sclerosis at work, how will colleagues react?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: disclosing multiple sclerosis at work, how will colleagues react?
# Complete Answer:. Retrying (2/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: disclosing multiple sclerosis at work, how will colleagues react?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: disclosing multiple sclerosis at work, how will colleagues react?
# Complete Answer:. Retrying (3/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: Will multiple sclerosis affect my career?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: Will multiple sclerosis affect my career?
# Complete Answer:. Retrying (1/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: Will multiple sclerosis affect my career?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: Will multiple sclerosis affect my career?
# Complete Answer:. Retrying (2/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: Will multiple sclerosis affect my career?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: Will multiple sclerosis affect my career?
# Complete Answer:. Retrying (3/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: List of multiple sclerosis symptoms\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: List of multiple sclerosis symptoms
# Complete Answer:. Retrying (1/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: List of multiple sclerosis symptoms\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: List of multiple sclerosis symptoms
# Complete Answer:. Retrying (2/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: List of multiple sclerosis symptoms\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: List of multiple sclerosis symptoms
# Complete Answer:. Retrying (3/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: Is the Covid-19 vaccine safe for people taking multiple sclerosis drugs?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: Is the Covid-19 vaccine safe for people taking multiple sclerosis drugs?
# Complete Answer:. Retrying (1/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: Is the Covid-19 vaccine safe for people taking multiple sclerosis drugs?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: Is the Covid-19 vaccine safe for people taking multiple sclerosis drugs?
# Complete Answer:. Retrying (2/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: Is the Covid-19 vaccine safe for people taking multiple sclerosis drugs?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: Is the Covid-19 vaccine safe for people taking multiple sclerosis drugs?
# Complete Answer:. Retrying (3/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: How do menopause symptoms relate to multiple sclerosis symptoms?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: How do menopause symptoms relate to multiple sclerosis symptoms?
# Complete Answer:. Retrying (1/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: How do menopause symptoms relate to multiple sclerosis symptoms?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: How do menopause symptoms relate to multiple sclerosis symptoms?
# Complete Answer:. Retrying (2/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: How do menopause symptoms relate to multiple sclerosis symptoms?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: How do menopause symptoms relate to multiple sclerosis symptoms?
# Complete Answer:. Retrying (3/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: Can I pass multiple sclerosis to other family members?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: Can I pass multiple sclerosis to other family members?
# Complete Answer:. Retrying (1/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: Can I pass multiple sclerosis to other family members?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: Can I pass multiple sclerosis to other family members?
# Complete Answer:. Retrying (2/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: Can I pass multiple sclerosis to other family members?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: Can I pass multiple sclerosis to other family members?
# Complete Answer:. Retrying (3/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: Can I work and study full-time with multiple sclerosis?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: Can I work and study full-time with multiple sclerosis?
# Complete Answer:. Retrying (1/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: Can I work and study full-time with multiple sclerosis?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: Can I work and study full-time with multiple sclerosis?
# Complete Answer:. Retrying (2/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: Can I work and study full-time with multiple sclerosis?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: Can I work and study full-time with multiple sclerosis?
# Complete Answer:. Retrying (3/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: Why get episode diagnosed by a doctor as a relapse of multiple sclerosis?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: Why get episode diagnosed by a doctor as a relapse of multiple sclerosis?
# Complete Answer:. Retrying (1/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: Why get episode diagnosed by a doctor as a relapse of multiple sclerosis?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: Why get episode diagnosed by a doctor as a relapse of multiple sclerosis?
# Complete Answer:. Retrying (2/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: Why get episode diagnosed by a doctor as a relapse of multiple sclerosis?\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: Why get episode diagnosed by a doctor as a relapse of multiple sclerosis?
# Complete Answer:. Retrying (3/3)...
# Error message: 0
# {"inputs": "You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.\nQuestion: Relapsing remitting multiple sclerosis\nComplete Answer:", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 502
# {'error': 'Bad Gateway'}
# Error on topic: You are a helpful medical knowledge assistant. Provide useful, complete, and scientifically-grounded answers to common consumer search queries about health.
# Question: Relapsing remitting multiple sclerosis
# Complete Answer:. Retrying (1/3)...
# Error message: 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 45, in generate_huggingface_answer(topics, max_retries, max_rows)
#      44 print(answer)
# ---> 45 topics.at[index, 'answer'] = answer[0]['generated_text']
#      46 break
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 57
#      55 # replace Nan with empty string
#      56 all_answers = all_answers.fillna("")
# ---> 57 questions_with_answers = generate_huggingface_answer(all_answers, max_rows= 100)
#      58 questions_with_answers.to_csv(out_path, index=False)
#
# Cell In[4], line 50, in generate_huggingface_answer(topics, max_retries, max_rows)
#      48 print(f"Error on topic: {prompt}. Retrying ({i+1}/3)...")
#      49 print(f"Error message: {e}")
# ---> 50 time.sleep(30)
#      51 if i == 2:
#      52     topics.at[index, 'answer'] = ""
#
# KeyboardInterrupt:
