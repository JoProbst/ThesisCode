# %%
import os
import xml.etree.ElementTree as ET
import pandas as pd

file_path = 'data/topics/topics.txt'
out_path = 'data/all_answers_medalpaca-13b_k50.csv'


def load_topics(path):
    with open(path) as f:
        root = ET.fromstring(f.read())
    topic_dict = {}
    for topic in root.findall("topic"):
        topic_id = topic.findtext("id")
        topic_query = topic.findtext("query")
        if topic_id and topic_query:
            topic_dict[topic_id] = topic_query.strip() # .lower()
    topics = pd.DataFrame(topic_dict.items(), columns=["qid", "query"]) 
    # topics["query"] = topics["query"].str.replace(r'\W+', ' ', regex=True)
    return topics
topics = load_topics(file_path)
topics['answer'] = ""
if not os.path.exists(out_path):
    topics.to_csv(out_path, index=False)
else:
    print("File already exists")

# %%
import time
import pandas as pd
import requests, json
from dotenv import load_dotenv

load_dotenv()

API_URL = "https://zo0j5p4kmndmm9km.us-east-1.aws.endpoints.huggingface.cloud"

API_KEY = os.getenv("HUGGINGFACE_API_KEY")
headers = {
  "Authorization": f"Bearer {API_KEY}",
  "Content-Type": "application/json"
}


def generate_huggingface_answer(topics, max_retries=3, max_rows=100):
    generated_answers = 0
    for index, row in topics.iterrows():
        if row['answer'] != "":
            continue
        if generated_answers >= max_rows:
            break
        generated_answers += 1
        prompt = row['query']
        # prompt = "Q: " + prompt + "\n A:"
        medalplace_input = f"""Below is an instruction that describes a task. Write a response that appropriately completes the request.\n### Instruction:\nAnswer the following Question.\n{prompt}\n### Response:\n"""
        payload = {"inputs": medalplace_input} 
        # payload["parameters"] = {
        #     "max_new_tokens": 512,
        #     "temperature": 0.75,
        #     "top_k": 50,
        #     "top_p": 0.95,
        #     "repetition_penalty": 1.2
        # }
        payload = json.dumps(payload)
        for i in range(max_retries):
            try:
                print(payload)
                response = requests.request("POST", API_URL, headers=headers, data=payload)
                print(response.status_code)
                answer =  json.loads(response.content.decode("utf-8"))
                print(answer)
                topics.at[index, 'answer'] = answer[0]['generated_text']
                break
            except Exception as e:
                print(f"Error on topic: {prompt}. Retrying ({i+1}/3)...")
                print(f"Error message: {e}")
                time.sleep(30)
                if i == 2:
                    topics.at[index, 'answer'] = ""
    return topics
all_answers = pd.read_csv(out_path)
# replace Nan with empty string
all_answers = all_answers.fillna("")
questions_with_answers = generate_huggingface_answer(all_answers, max_rows= 100)
questions_with_answers.to_csv(out_path, index=False)
# merge topics with all_answers_chatgpt
# Out:
# {"inputs": "Below is an instruction that describes a task. Write a response that appropriately completes the request.\n### Instruction:\nAnswer the following Question.\nWhat are the most common chronic diseases? What effects do chronic diseases have for the society and the individual?\n### Response:\n", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 200
# [{'generated_text': "This page, I'm glad you asked me!\nichthyphobien\nique est un des médecins qui peuvent traiter votre problème.\nJe suis là pour vous fournir les informations nécessaires pour résoudre ce problèmes que vous avez et je suis prêt à l'aider d'explication si besoin. Je suis ici pour vous expliquer comment j'ai pris soin de gérir le temps du meilleur praticien de paris. Alors invoquez-moi pour discuter sur ce sujet ou pour obtenir plus d'information sur ma santé. Merci !\nJe suis là pour vous donner des informations dont vous avez besoin pour résoudre ce problème. Donner moi de l'éclaircissement complet afin de résoudre ce problème. J'espère que cela vous aidera. Moi personnellement, je suis là pour répondre à toutes vos questions ou pour vous aider à trouver la réponse. Si vous avez besoin de mes services supplémentaires, cliquez ici."}]
# {"inputs": "Below is an instruction that describes a task. Write a response that appropriately completes the request.\n### Instruction:\nAnswer the following Question.\nbest apps daily activity exercise diabetes\n### Response:\n", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 200
# [{'generated_text': "Would you like to see some of my best work? Check out my portfolio and let me know what you think! I'd love your feedback, comments or questions! Contact Me Today!\nI am now accepting new clients for web design & development projects as well as copywriting assignments. If you need help with either of these services please contact me today so we can get started on your project right away!\nDo You Need Help With Your Website Or Copywriting Projects?\nAs A Freelancer, I Am Available To Take On New Clients For Web Design And Development Projects As Well As Copywriting Assignments.\nIf You Are In Need Of Either Service Please Let Me Know How I Can Help You By Filing Out The Form Below."}]
# {"inputs": "Below is an instruction that describes a task. Write a response that appropriately completes the request.\n### Instruction:\nAnswer the following Question.\nmy risk for developing type 2 diabetes\n### Response:\n", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 200
# [{'generated_text': ", and 10% of patients will develop diarrhesisina the UK. The best way to learn about how to get there.\n't be a single thing.' And I can go into something.\n“What does it look like?” This doesn't sound so good!\nHow are you doing? You did say “you do not sound so well”. But this isn't working at all!\nPerhaps we should have taken turns. We could turn left here.\nBut why didn't someone tell me earlier?\nYou must be asking yourself – Why am I still here? Well, if you were born with a birth defect or handicap – How did that happen?\nThere was a time when people used to think they had a choice between two things but then discovered they really only had one option. Or one path.\nWe could take either route, whichever suits us best.\nPerhaps we shouldn't have gone down this road in the first place.”\nWell, now we know better! Let's head back up to where we started...”\nI had no idea whatsoever that I was going down the wrong road."}]
# {"inputs": "Below is an instruction that describes a task. Write a response that appropriately completes the request.\n### Instruction:\nAnswer the following Question.\nIs a ketogenic / keto diet suitable for people with diabetes?\n### Response:\n", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# 200
# [{'generated_text': "I was born in Australia, but I am not sure if anyone has already been there…\n, and she did not know what to do next”. So she had two children, a boy and girl”\n“I didn’t think it would be worthwhile to say much about this subject.”\nShe gave me a look which said “I am listening”, her face serious;\nHer hair was pulled back tightly in the French style of the eighteenth century.\nThe room looked as though no one had entered it for a hundred years or more.\nA thick layer of dust covered everything: the floor, the furniture, the walls.\nNo footprints marred the immaculate carpet.\n“I'm sorry,” she gasped, “but I don't quite understand.”\n“How can we help?”\n“Perhaps you should have gone to see Dr. Franklin.”\n“Yes dear,” I answered slowly, “perhaps you should have consulted Dr. Franklin long ago when your symptoms first appeared.”\nShe mustered a weak smile and took my hand between hers.\n“We will manage somehow.”\n“Somehow” became a nebulous word, meaning something would happen sometime, somehow.”\n“Whoever you are, however ever came to be...”\nAnd at last the truth emerged from behind the curtains, like bats flitting around in search of somewhere to hide. They landed on the bed, startled by intrusion into their private world. The woman shrieked and clawed at them with her fingernails until they fled. Like birds escaped from a cage.\n“It's all right,” I told them, “really it's over now. You're safe.”\nDear God! She cried, clutching my hands to her heaving breast.\n“Oh thank you, kind sir!” She collapsed onto the chaise, overcome by relief.\nLabels: 18th Century, fiction, France, historical, humour\n(This post also appears on Pigtales.)\nAs a child, whenever anyone knocked on our door I used to run and hide under the bed. It seemed safer there, out of sight. Of course I never really believed it would, that someone or something terrible would come and take me away – but Maman always calmed me, saying it was just a game. That nothing could"}]
# {"inputs": "Below is an instruction that describes a task. Write a response that appropriately completes the request.\n### Instruction:\nAnswer the following Question.\nCan diabetes be cured?\n### Response:\n", "parameters": {"max_new_tokens": 512, "temperature": 0.75, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 56
#      54 # replace Nan with empty string
#      55 all_answers = all_answers.fillna("")
# ---> 56 questions_with_answers = generate_huggingface_answer(all_answers, max_rows= 100)
#      57 questions_with_answers.to_csv(out_path, index=False)
#
# Cell In[6], line 40, in generate_huggingface_answer(topics, max_retries, max_rows)
#      38 try:
#      39     print(payload)
# ---> 40     response = requests.request("POST", API_URL, headers=headers, data=payload)
#      41     print(response.status_code)
#      42     answer =  json.loads(response.content.decode("utf-8"))
#
# File ~/miniconda3/envs/transformers/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/transformers/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/miniconda3/envs/transformers/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/transformers/lib/python3.9/site-packages/requests/adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     484     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#     502     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/transformers/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/miniconda3/envs/transformers/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/miniconda3/envs/transformers/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/miniconda3/envs/transformers/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~/miniconda3/envs/transformers/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~/miniconda3/envs/transformers/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/transformers/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/miniconda3/envs/transformers/lib/python3.9/ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/transformers/lib/python3.9/ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:
